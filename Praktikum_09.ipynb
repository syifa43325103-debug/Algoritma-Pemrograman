# %% [markdown]
# <a href="https://colab.research.google.com/github/syifa43325103-debug/Algoritma-Pemrograman/blob/main/Praktikum_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 - Menggunakan Modul

# %%
import math

angka = 16
hasil1  = math.sqrt(angka)
hasil2 = math.pow(2, 5)
print("Akar kuadrat dari", angka, "=", hasil1)
print("2 pangkat 5 =", hasil2)
# Out:
# Akar kuadrat dari 16 = 4.0
# 2 pangkat 5 = 32.0

# %% [markdown]
# Praktikum 02 - Menggunakan from ... import ...

# %%
from math import sqrt

angka = 25
hasil = sqrt(angka)
print("Akar kuadrat dari", angka, "=", hasil)
# Out:
# Akar kuadrat dari 25 = 5.0

# %% [markdown]
# Praktikum 03 - Memberi Alias Modul

# %%
import numpy as np

data = np.array([1, 2, 3])
print("Isi array=", data)
# Out:
# Isi array= [1 2 3]

# %% [markdown]
# Praktikum 04 - Eksplorasi math, random, dan sys

# %%
import math
import random
import sys

hasil1 = math.sqrt(81)
hasil2 = random.randint(1, 10)
versi = sys.version

print("Akar kuadrat 81 =", hasil1)
print("Angka acak 1-10 =", hasil2)
print("Versi Python =", versi)
# Out:
# Akar kuadrat 81 = 9.0
# Angka acak 1-10 = 4
# Versi Python = 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# Praktikum 05 - Membuat Modul Sendiri

# %%
# %%writefile modulku.py

def halo(nama):
    print(f"Halo, {nama}! Selamat belajar Python di Polines.")
# Out:
# Writing modulku.py

# %%
import modulku

modulku.halo("Mahasiswa Polines")
# Out:
# Halo, Mahasiswa Polines! Selamat belajar Python di Polines.

# %% [markdown]
# Praktikum 06 - Instalasi Modul dengan pip

# %%
# !pip install requests

# %%
import requests

response = requests.get("https://www.polines.ac.id")
print("Status code:", response.status_code)
# Out:
# Status code: 403

# %% [markdown]
# Penugasan No. 3 - Ekperimen dengan Modul math

# %%
import math

def hitung_luas_lingkaran(jari_jari):
    luas = math.pi * jari_jari ** 2
    return luas

luas_7 = hitung_luas_lingkaran(7)
print(f"Luas lingkungan dengan r=7 adalah {luas_7}")

luas_10 = hitung_luas_lingkaran(10)
print(f"Luas lingkaran dengan r=10 adalah {luas_10}")
# Out:
# Luas lingkungan dengan r=7 adalah 153.93804002589985
# Luas lingkaran dengan r=10 adalah 314.1592653589793

# %% [markdown]
# Penugasan No. 4 - Eksperimen dengan Modul Random

# %%
import random

print("Menampilkan 5 angka acak antara 1 dan 100:")

for _ in range(5):
    angka = random.randint(1, 100)
    print(angka)
# Out:
# Menampilkan 5 angka acak antara 1 dan 100:
# 53
# 13
# 18
# 43
# 46

# %% [markdown]
# Penugasan N0. 5 - Modul sys

# %%
import sys

versi1 = sys.platform
versi2 = sys.version

print("----- Informasi Sistem -----")
print("Platform Sistem Operasi=", versi1)
print("Versi Python =", versi2)
# Out:
# ----- Informasi Sistem -----
# Platform Sistem Operasi= linux
# Versi Python = 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# Penugasan No. 6 - Modul Buatan Sendiri

# %%
# %%writefile konversi.py

def celcius_ke_fahrenheit(celcius):
    fahrenheit = (celcius * 9/5) + 32
    return fahrenheit

def fahrenheit_ke_celcius(f):
    celcius = (f - 32) * 5/9
    return celcius
# Out:
# Writing konversi.py

# %%
import konversi

print("-----Menggunakan Modul Konversi-----")

suhu_celcius = 100
suhu_fahrenheit = 212

hasil_fahrenheit = konversi.celcius_ke_fahrenheit(suhu_celcius)
hasil_celcius = konversi.fahrenheit_ke_celcius(suhu_fahrenheit)

print(f"{suhu_celcius} Celcius adalah {hasil_fahrenheit} Fahrenheit")
print(f"{suhu_fahrenheit} Fahrenheit adalah {hasil_celcius} Celcius")
# Out:
# -----Menggunakan Modul Konversi-----
# 100 Celcius adalah 212.0 Fahrenheit
# 212 Fahrenheit adalah 100.0 Celcius

# %% [markdown]
# Penugasan No. 7 - Instalasi Library Pihak Ketiga

# %%
# !pip install pandas

# %%
import pandas as pd

data = {
    "NIM": ["101", "102", "103"],
    "Nama": ["Carmen", "Ian", "Stella"],
    "Prodi": ["TRK", "IK", "TE"],
}

df = pd.DataFrame(data)
print("---Data Mahasiswa---")
print(df)
# Out:
# ---Data Mahasiswa---
#    NIM    Nama Prodi
# 0  101  Carmen   TRK
# 1  102     Ian    IK
# 2  103  Stella    TE

# %% [markdown]
# Penugasan No. 8 - Studi Kasus Mini

# %%
# %%writefile laporan.py

def cetak_laporan(skor, total_soal):
    print("\n--- KUIS SELESAI ---")
    print(f"Skor Anda: {skor} dari {total_soal} soal.")

    persentase = (skor / total_soal) * 100
    print(f"Nilai Akhir: {persentase:.1f}")

    if persentase == 100:
        print("Sempurna! Kerja bagus!")
    elif persentase >= 70:
        print("Bagus, anda berhasil!")
    else:
        print("Teruslah berlatih!")
# Out:
# Overwriting laporan.py

# %%
import laporan
import random

print("--- KUIS PENJUMLAHAN SEDERHANA ---")
print("Jawablah 3 soal berikut:")

skor = 0
total_soal = 3

for i in range(total_soal):
    a = random.randint(1, 20)
    b = random.randint(1, 20)
    jawaban_benar = a + b

    try:
      jawaban_user = int(input(f"Soal {i+1}: {a} + {b} = "))

      if jawaban_user == jawaban_benar:
          print("Benar!")
          skor += 1
      else:
          print(f"Salah. Jawaban yang benar adalah {jawaban_benar}")

    except ValueError:
        print("Input tidak valid. Soal ini dianggap salah.")
    laporan.cetak_laporan(skor, total_soal)
# Out:
# --- KUIS PENJUMLAHAN SEDERHANA ---
# Jawablah 3 soal berikut:
# Soal 1: 8 + 7 = 15
# Benar!
#
# --- KUIS SELESAI ---
# Skor Anda: 1 dari 3 soal.
# Nilai akhir: 33.3
# Coba lagi!
# Soal 2: 12 + 8 = 8
# Salah. Jawaban yang benar adalah 20
#
# --- KUIS SELESAI ---
# Skor Anda: 1 dari 3 soal.
# Nilai akhir: 33.3
# Coba lagi!
# Soal 3: 7 + 7 = 14
# Benar!
#
# --- KUIS SELESAI ---
# Skor Anda: 2 dari 3 soal.
# Nilai akhir: 66.7
# Coba lagi!
