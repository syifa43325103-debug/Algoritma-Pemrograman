# %% [markdown]
# <a href="https://colab.research.google.com/github/syifa43325103-debug/Algoritma-Pemrograman/blob/main/Praktikum_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 - Fungsi Dasar dengan def

# %%
def sapa():
  print("Halo, selamat datang di Politeknik Negeri Semarang!")

sapa()
# Out:
# Halo, selamat datang di Politeknik Negeri Semarang!

# %% [markdown]
# Praktikum 02 - Fungsi dengan Parameter dan Return

# %%
def tambah(a, b):
  return a + b

hasil = tambah(7,3)
print("Hasil penjumlahan:", hasil)
# Out:
# Hasil penjumlahan: 10

# %% [markdown]
# Praktikum 03 - Fungsi dengan Default Argument

# %%
def sapa(nama="Mahasiswa"):
  print(f"Halo, {nama}!")

sapa ()
sapa("Andi")
# Out:
# Halo, Mahasiswa!
# Halo, Andi!

# %% [markdown]
# Praktikum 04 - Fungsi dengan *args dan **kwargs

# %%
def jumlahkan(*args):
  return sum(args)

def biodata(**kwargs):
    for key, value in kwargs.items():
      print(f"{key}: {value}")

print("Total:", jumlahkan(1, 2, 3, 4, 5))
biodata(Nama="Budi", Umur=20, Prodi="TRK")
# Out:
# Total: 15
# Nama: Budi
# Umur: 20
# Prodi: TRK

# %% [markdown]
# Praktikum 05 - Scope Variabel

# %%
x = 10

def ubah():
  x = 5
  print("Nilai lokal:", x)

ubah()
print("Nilai global:", x)
# Out:
# Nilai lokal: 5
# Nilai global: 10

# %% [markdown]
# Praktikum 06 - Fungsi Lambda

# %%
kali = lambda x, y: x * y
print("Hasil perkalian:", kali(4, 5))
# Out:
# Hasil perkalian: 20

# %% [markdown]
# Praktikum 07 - Fungsi Decorator

# %%
def decorator_sapa (fungsi):
  def wrapper():
    print("Sebelum fungsi dijalankan...")
    fungsi()
    print("Setelah fungsi dijalankan...")
  return wrapper

@decorator_sapa
def sapa():
  print("Halo, Mahasiswa Polines!")

sapa()
# Out:
# Sebelum fungsi dijalankan...
# Halo, Mahasiswa Polines!
# Setelah fungsi dijalankan...

# %% [markdown]
# Praktikum 08 - Studi Kasus: Menghitung Rata-rata Nilai Mahasiswa

# %%
def hitung_rata(data):
  return sum(data) / len(data)

nilai = [80, 90,85]
rata = hitung_rata(nilai)

print("Rata-rata nilai:", rata)
# Out:
# Rata-rata nilai: 85.0

# %% [markdown]
# Penugasan No. 3 - Fungsi Sederhana

# %%
def sapa(nama, prodi):
  print(f"Halo, nama saya {nama}, saya dari {prodi}")

sapa("Carmen", "Teknologi Rekayasa Komputer")
sapa("Ian", "Teknik Telekomunikasi")
sapa("Stella", "Teknik Informatika")
# Out:
# Halo, nama saya Carmen, saya dari Teknologi Rekayasa Komputer
# Halo, nama saya Ian, saya dari Teknik Telekomunikasi
# Halo, nama saya Stella, saya dari Teknik Informatika

# %% [markdown]
# Penugasan No. 4 - Fungsi dengan Parameter dan Return

# %%
def luas(panjang, lebar):
  return panjang * lebar

hasil = luas(8, 9)
print("Luas persegi panjang (8 * 9) adalah:", hasil)
hasil = luas(5, 5)
print("Luas persegi panjang (5 * 5) adalah:", hasil)
hasil = luas(10, 6)
print("Luas persegi panjang (10 * 6) adalah:", hasil)
# Out:
# Luas persegi panjang (8 * 9) adalah: 72
# Luas persegi panjang (5 * 5) adalah: 25
# Luas persegi panjang (10 * 6) adalah: 60

# %% [markdown]
# Penugasan No. 5 - Fungsi dengan Default Argument

# %%
def salam(waktu="Pagi", nama="Mahasiswa"):
  print(f"Selamat, {waktu}, {nama}!")

salam("Sore", "Budi")
salam("Malam")
salam()
# Out:
# Selamat, Sore, Budi!
# Selamat, Malam, Mahasiswa!
# Selamat, Pagi, Mahasiswa!

# %% [markdown]
# Penugasan No. 6 - *Fungsi dengan args

# %%
def jumlahkan_semua(*args):
  return sum(args)

print("Total Uji 1:", jumlahkan_semua(1, 2, 3))
print("Total Uji 2:", jumlahkan_semua(3, 5, 7, 6, 8))
print("Total Uji 3:", jumlahkan_semua(3, 5, 7, 6, 8, 9, 5))
# Out:
# Total Uji 1: 6
# Total Uji 2: 29
# Total Uji 3: 43

# %% [markdown]
# Penugasan No. 7 - **Fungsi dengan kwargs

# %%
def info_barang(**kwargs):
    for key, value in kwargs.items():
      print(f"{key}: {value}")

info_barang(Nama="Buku", Harga=15000, Stok=30)
# Out:
# Nama: Buku
# Harga: 15000
# Stok: 30

# %% [markdown]
# Penugasan No. 8 - Scope Variabel

# %%
x = 100

def ubah():
  x = 50
  print("Nilai lokal:", x)

ubah()
print("Nilai global:", x)
# Out:
# Nilai lokal: 50
# Nilai global: 100

# %% [markdown]
# Penugasan 9 - Fungsi Lambda

# %%
kuadrat = lambda x : x ** 2
print("Hasil kuadrat:", kuadrat(4))
keliling_lingkaran = lambda r : 2 * 3.14 * r
print("Hasil keliling_lingkaran:", keliling_lingkaran (8))
# Out:
# Hasil kuadrat: 16
# Hasil keliling_lingkaran: 50.24

# %% [markdown]
# Penugasan 10 - Fungsi Decorator

# %%
def decorator_halo (fungsi):
  def wrapper():
    print("Memulai fungsi...")
    fungsi()
    print("Fungsi selesai dijalankan")
  return wrapper

@decorator_halo
def halo():
  print("Halo, Mahasiswa Polines!")

halo()
# Out:
# Memulai fungsi...
# Halo, Mahasiswa Polines!
# Fungsi selesai dijalankan

# %% [markdown]
# Penugasan No. 11 - Studi Kasus Nyata - Program Nilai

# %%
nilai_akhir = lambda tugas, ujian: (tugas*0.4) + (ujian*0.6)

def input_nilai():
  list_nilai = []
  jumlah = int(input("Jumlah mata kuliah: "))

  for i in range(jumlah):
    print(f"\nMata Kuliah ke-{i+1}")
    tugas = float(input("Nilai tugas: "))
    ujian = float(input("Nilai ujian: "))

    nilai_jadi = nilai_akhir(tugas, ujian)
    list_nilai.append(nilai_jadi)
  return list_nilai

def hitung_rata(data_nilai):
  return sum(data_nilai) / len(data_nilai)

def status_kelulusan(rata):
  if rata >= 60:
    return "LULUS"
  else:
    return "TIDAK LULUS"

nilai_mahasiswa = input_nilai()

print("--------------------------------------")

if nilai_mahasiswa:
  rata_rata = hitung_rata(nilai_mahasiswa)
  status = status_kelulusan(rata_rata)

  print(f"Rata-rata Nilai-nilai akhir: {nilai_mahasiswa}")
  print(f"Rata-rata: {rata_rata:.2f}")
  print(f"Status kelulusan: {status}")
# Out:
# Jumlah mata kuliah: 2
#
# Mata Kuliah ke-1
# Nilai tugas: 70
# Nilai ujian: 89
#
# Mata Kuliah ke-2
# Nilai tugas: 90
# Nilai ujian: 98
# --------------------------------------
# Rata-rata Nilai-nilai akhir: [81.4, 94.8]
# Rata-rata: 88.10
# Status kelulusan: LULUS
